# %%
from plot_utilities import matplotlib_nikita_style
matplotlib_nikita_style()

# %%
import matplotlib.pyplot as plt
import yfinance as yf
# Get the data for the stock AAPL
data = yf.download('AAPL','2016-01-01','2020-01-01')
# Plot the close price of the AAPL
data['Adj Close'].plot()
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Text(0.5, 0, 'Date')

# %%
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd

# Define the ticker list
tickers_list = ['AAPL', 'VZ', 'MSFT', 'TSLA', 'INTC']
data = pd.DataFrame(columns=tickers_list)
# Fetch the data
for ticker in tickers_list:
    data[ticker] = yf.download(ticker, '2018-01-01','2020-01-01')['Adj Close']
# Print first 5 rows of the data
print(data.head())
# Plot all the close prices
((data.pct_change()+1).cumprod()).plot()
plt.ylabel('Price')
plt.xlabel('Date')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                   AAPL         VZ       MSFT        TSLA       INTC
# Date
# 2018-01-02  166.804016  48.525623  83.029594  320.529999  44.369122
# 2018-01-03  166.774963  47.528469  83.415993  317.250000  42.863327
# 2018-01-04  167.549622  47.682571  84.150192  314.619995  42.077274
# 2018-01-05  169.457214  47.573784  85.193497  316.579987  42.370857
# 2018-01-08  168.827820  47.492199  85.280426  336.410004  42.370857
# Text(0.5, 0, 'Date')

# %%
import yfinance as yf
import pandas as pd
import pyfolio as pf

# Define the ticker list
tickers_list = ['AAPL', 'VZ', 'MSFT', 'TSLA', 'INTC']
data = pd.DataFrame(columns=tickers_list)
# Fetch the data
for ticker in tickers_list:
    data[ticker] = yf.download(ticker, '2018-01-01','2020-01-01')['Adj Close']

# Compute the returns of individual stocks and then compute the daily mean returns.
data = data.pct_change().dropna().mean(axis=1)
# Print first 5 rows of the data
print(data.head())
pf.create_full_tear_sheet(data)
# Out:
# /Users/tafintse/anaconda3/lib/python3.6/site-packages/pyfolio/pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Date
# 2018-01-03   -0.012048
# 2018-01-04   -0.001988
# 2018-01-05    0.006942
# 2018-01-08    0.011646
# 2018-01-09   -0.007516
# dtype: float64
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2018-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2019-12-31</td></tr>
# ...

# %%
from alpha_vantage.timeseries import TimeSeries

# initialize TS object with API key and output format
ts = TimeSeries(key='ZWKNDUDFVHVQXBTM', output_format='pandas')
# Get the data
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='compact')
# Print the data
print(data.head())
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2020-03-20 10:13:00  144.705   144.92  144.50   144.590   122531.0
# 2020-03-20 10:12:00  144.840   144.84  144.15   144.700   162141.0
# 2020-03-20 10:11:00  144.260   144.83  144.09   144.830   125564.0
# 2020-03-20 10:10:00  144.450   144.70  144.20   144.330   113332.0
# 2020-03-20 10:09:00  144.500   144.78  144.07   144.455   146772.0
